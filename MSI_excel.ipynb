# %%
import pandas as pd

# %%
#!pip install openpyxl

# %%
df=pd.read_excel('MSI.xlsx', sheet_name='KTL     ')

# %%
df.head()
# Out:
#                                      ABC Ltd. Unnamed: 1 Unnamed: 2  \
# 0                                         NaN        NaN        NaN
# 1  Management Information System (MIS) Report        NaN        NaN
# 2                                         NaN        NaN        NaN
# 3                                       Floor       Line     Buyer
# 4                                         NaN        NaN        NaN
#
#        Unnamed: 3 Unnamed: 4 Unnamed: 5  Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0             NaN        NaN        NaN         NaN        NaN        NaN
# 1             NaN        NaN        NaN         NaN        NaN        NaN
# 2             NaN        NaN        NaN         NaN        NaN
# 3  Sales Order No   Style No       Item  Start Date     Wr- Hr    Wr- Hr.
# 4             NaN        NaN        NaN         NaN        NaN        NaN
#
#         Unnamed: 9  ... Unnamed: 148 Unnamed: 149   Unnamed: 150  \
# ...
